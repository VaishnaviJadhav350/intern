# %% [markdown]
# ### What is Pandas?
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.
#
# Pandas is a Python library used for:
#
#     Data analysis
#     Data manipulation
#     Data cleaning
#     Handling structured data (tables)
#
# It works mainly with tabular data like Excel sheets, CSV files, databases, etc.

# %% [markdown]
# ### Why Use Pandas?
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.
#
# Relevant data is very important in data science.

# %% [markdown]
# ### Data Structures in Pandas:
# Pandas provides two data structures for manipulating data which are as follows:
#
# 1. Pandas Series
# 2. Pandas Dataframe

# %% [markdown]
# 1. Series:
#
#
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.
#
# A Pandas Series is one-dimensional labeled array capable of holding data of any type (integer, string, float, Python objects etc.).
# The axis labels are collectively called indexes.

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd 

s = pd.Series() 
print("Pandas Series: ", s) 
data = pd.array(['g', 'e', 'e', 'k', 's']) 
  
s = pd.Series(data) 
print("Pandas Series:\n", s)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %% [markdown]
# ### Attributes:

# %% [markdown]
# ### Series Attributes
# Attribute   |	Meaning
# ------------|----------------------
# s.index	    |    Index labels
# s.values    |	Data values
# s.dtype	    |    Data type
# s.size	    |    Number of elements

# %%
s=pd.Series([10, 20, 30, 40, 50])
print(s.index)
print(s.values)
print(s.dtype)
print(s.size)
# Out:
# RangeIndex(start=0, stop=5, step=1)
# [10 20 30 40 50]
# int64
# 5

# %%
## Create labels:

import pandas as pd

a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
print(a[0])
print(myvar["y"])
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 1
# 7

# %% [markdown]
# ### operations:
# 1. Arithmetic Operation
# 2. Filtering Operation
# 3. Statistical Operations
# 4. String Operations
# 5. Handling missing Values
# 6. Apply Function

# %%
## 1. Arithmetic Operation

print(s + 5)

print(s * 2)

print(s - 10)

print(s / 2)
# Out:
# 0    15
# 1    25
# 2    35
# 3    45
# 4    55
# dtype: int64
# 0     20
# 1     40
# 2     60
# 3     80
# 4    100
# dtype: int64
# 0     0
# 1    10
# 2    20
# 3    30
# 4    40
# dtype: int64
# 0     5.0
# 1    10.0
# 2    15.0
# 3    20.0
# 4    25.0
# dtype: float64

# %%
## 2. Filtring Operation

s[s > 20]
# Out:
# 0    50
# 2    30
# 4    40
# dtype: int64

# %%
## 3. Statistical Operation

print("Sum:", s.sum())
print("Mean:", s.mean())
print("Max:", s.max())
print("Min:", s.min())
print("Std:", s.std())
# Out:
# Sum: 150
# Mean: 30.0
# Max: 50
# Min: 10
# Std: 15.811388300841896

# %%
## 4. String Operation:

names = pd.Series(["amit", "neha", "ravi"])

names.str.upper()
names.str.contains("a")
names.str.len()
names.str.replace("a", "@")
# Out:
# 0    @mit
# 1    neh@
# 2    r@vi
# dtype: object

# %%
## 5. Handling Missing Values
s = pd.Series([10, None, 30, None])

s.isnull()
s.fillna(0)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool
# 0    10.0
# 1     0.0
# 2    30.0
# 3     0.0
# dtype: float64

# %%
## 6. Apply Function

s.apply(lambda x: x * 2)
# Out:
# 0    100
# 1     40
# 2     60
# 3     20
# 4     80
# dtype: int64

# %%
## Sorting Values:
s = pd.Series([50, 20, 30, 10, 40])
s.sort_values()
## Sorting Index:
s.sort_index()
# Out:
# 3    10
# 1    20
# 2    30
# 4    40
# 0    50
# dtype: int64
# 0    50
# 1    20
# 2    30
# 3    10
# 4    40
# dtype: int64

# %% [markdown]
# - Key/Value Objects as Series:

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
## Create a Series using only data from "day1" and "day2":

import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories, index = ["day1", "day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# 2. DataFrames:
#
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# Series is like a column, a DataFrame is the whole table.

# %%
## Create a DataFrame from two Series:

import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data)

print(df)

## Pandas use the loc attribute to return one or more specified row(s)
print(df.loc[1])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# calories    380
# duration     40
# Name: 1, dtype: int64

# %% [markdown]
# With the index argument, you can name your own indexes.

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df) 

print(df.loc["day2"])  ## Access a specific row

## operations on DataFrames:

print(df.head(2))  #prints first two rows
print(df.tail(2))  #prints last two rows
print(df.shape)  #prints number of rows and columns
print(df.columns)  #prints column names
print(df.size)  #prints total number of elements
print(df.dtypes)  #prints data types of each column
print(df.values)  #prints data as a numpy array
print(df.index)  #prints index labels
print(df['duration']) #prints specific column
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# calories    380
# duration     40
# Name: day2, dtype: int64
#       calories  duration
# day1       420        50
# day2       380        40
#       calories  duration
# day2       380        40
# day3       390        45
# (3, 2)
# Index(['calories', 'duration'], dtype='object')
# 6
# calories    int64
# duration    int64
# dtype: object
# [[420  50]
#  [380  40]
#  [390  45]]
# Index(['day1', 'day2', 'day3'], dtype='object')
# day1    50
# day2    40
# day3    45
# Name: duration, dtype: int64

# %% [markdown]
# ### Pandas Merging, Joining and Concatenating

# %%
import pandas as pd

data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}

df = pd.DataFrame(data1, index=[0, 1, 2, 3])

df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])
print(df)
print(df1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#      Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %% [markdown]
# #### 1. Mearge:
# Merge combines DataFrames using common column(s)

# %%
result = pd.merge(df, df1, on="Age") ##Merges rows where Age is common
print(result)
# Out:
# Empty DataFrame
# Columns: [Name_x, Age, Address_x, Qualification_x, Name_y, Address_y, Qualification_y]
# Index: []

# %% [markdown]
# - Types of Merge:
#
# Type    |Description
# --------|-------------------------------
# Inner	|"inner"	Common rows only
# Left	|"left"	All left + matching right
# Right	|"right"	All right + matching left
# Outer	|"outer"	All rows

# %%
result = pd.merge(df, df1, on="Age", how="left")
print(result)
# Out:
#    Name_x  Age  Address_x Qualification_x Name_y Address_y Qualification_y
# 0     Jai   27     Nagpur             Msc    NaN       NaN             NaN
# 1  Princi   24     Kanpur              MA    NaN       NaN             NaN
# 2  Gaurav   22  Allahabad             MCA    NaN       NaN             NaN
# 3    Anuj   32    Kannuaj             Phd    NaN       NaN             NaN

# %%
result= pd.merge(df, df1, on="Age", how="right")
print(result)
# Out:
#   Name_x  Age Address_x Qualification_x  Name_y  Address_y Qualification_y
# 0    NaN   17       NaN             NaN    Abhi     Nagpur           Btech
# 1    NaN   14       NaN             NaN  Ayushi     Kanpur             B.A
# 2    NaN   12       NaN             NaN  Dhiraj  Allahabad            Bcom
# 3    NaN   52       NaN             NaN  Hitesh    Kannuaj          B.hons

# %%
result = pd.merge(df, df1, on="Address", how="inner")
print(result)
# Out:
#    Name_x  Age_x    Address Qualification_x  Name_y  Age_y Qualification_y
# 0     Jai     27     Nagpur             Msc    Abhi     17           Btech
# 1  Princi     24     Kanpur              MA  Ayushi     14             B.A
# 2  Gaurav     22  Allahabad             MCA  Dhiraj     12            Bcom
# 3    Anuj     32    Kannuaj             Phd  Hitesh     52          B.hons

# %%
result= pd.merge(df, df1, on="Age", how="outer")
print(result)
# Out:
#    Name_x  Age  Address_x Qualification_x  Name_y  Address_y Qualification_y
# 0     NaN   12        NaN             NaN  Dhiraj  Allahabad            Bcom
# 1     NaN   14        NaN             NaN  Ayushi     Kanpur             B.A
# 2     NaN   17        NaN             NaN    Abhi     Nagpur           Btech
# 3  Gaurav   22  Allahabad             MCA     NaN        NaN             NaN
# 4  Princi   24     Kanpur              MA     NaN        NaN             NaN
# 5     Jai   27     Nagpur             Msc     NaN        NaN             NaN
# 6    Anuj   32    Kannuaj             Phd     NaN        NaN             NaN
# 7     NaN   52        NaN             NaN  Hitesh    Kannuaj          B.hons

# %% [markdown]
# #### 2. Concatanating:
# Concat stacks DataFrames row-wise or column-wise.
#
# This function allows us to combine multiple DataFrames into one by specifying the axis (rows or columns).

# %%
frames = [df, df1]
frames

con=pd.concat(frames)
con
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %% [markdown]
# - Concatenating DataFrames by Setting Logic on Axes
#
# We can modify the concatenation by setting logic on the axes. Specifically we can choose whether to take the Union (join='outer') or Intersection (join='inner') of columns.

# %%
ijoin = pd.concat([df, df1],axis=0, join='inner')  ## axis=0 : column wise
ijoin
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
result= pd.concat([df, df1], axis=1, join='outer')  ## axis=1 : row wise
result
# Out:
#      Name   Age    Address Qualification    Name   Age    Address  \
# 0     Jai  27.0     Nagpur           Msc     NaN   NaN        NaN
# 1  Princi  24.0     Kanpur            MA     NaN   NaN        NaN
# 2  Gaurav  22.0  Allahabad           MCA     NaN   NaN        NaN
# 3    Anuj  32.0    Kannuaj           Phd     NaN   NaN        NaN
# 4     NaN   NaN        NaN           NaN    Abhi  17.0     Nagpur
# 5     NaN   NaN        NaN           NaN  Ayushi  14.0     Kanpur
# 6     NaN   NaN        NaN           NaN  Dhiraj  12.0  Allahabad
# 7     NaN   NaN        NaN           NaN  Hitesh  52.0    Kannuaj
#
#   Qualification
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4         Btech
# 5           B.A
# 6          Bcom
# 7        B.hons

# %% [markdown]
# #### 3. Joinning:
#
# Join combines DataFrames using index by default.
#
# - Types:
#
# Type    |Description
# --------|-------------------------------
# Inner	|"inner"	Common rows only
# Left	|"left"	All left + matching right
# Right	|"right"	All right + matching left
# Outer	|"outer"	All rows

# %%
import pandas as pd

data1 = {'Name': ['Gaurav', 'Anuj'],
         'Age': [22, 32],
         }

data2 = {'Address': ['Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA']
        }

df = pd.DataFrame(data1, index=[0, 1])

df1 = pd.DataFrame(data2, index=[4, 5])
print(df)
print(df1)
# Out:
#      Name  Age
# 0  Gaurav   22
# 1    Anuj   32
#      Address Qualification
# 4  Allahabad           Msc
# 5    Kannuaj            MA

# %%
df.join(df1, how="left")
# Out:
#      Name   Age    Address Qualification
# 0  Gaurav  22.0        NaN           NaN
# 1    Anuj  32.0        NaN           NaN
# 4     NaN   NaN  Allahabad           Msc
# 5     NaN   NaN    Kannuaj            MA

# %%
df.join(df1, how="right")
# Out:
#   Name  Age    Address Qualification
# 4  NaN  NaN  Allahabad           Msc
# 5  NaN  NaN    Kannuaj            MA

# %%
df.join(df1, how="inner")
# Out:
# Empty DataFrame
# Columns: [Name, Age, Address, Qualification]
# Index: []

# %%
df.join(df1, how="outer")
# Out:
#      Name   Age    Address Qualification
# 0  Gaurav  22.0        NaN           NaN
# 1    Anuj  32.0        NaN           NaN
# 4     NaN   NaN  Allahabad           Msc
# 5     NaN   NaN    Kannuaj            MA

# %% [markdown]
# - Load Files Into a DataFrame:
#
# ### CSV FILE:
#
# If your data sets are stored in a file, Pandas can load them into a DataFrame.

# %% [markdown]
# - StringIO:
#
# StringIO is used to convert a string into a file - like object so pandas can read it as a file
#
# (pandas function la (like read_csv()) la file path kinva file - like object lagto.
# Pan data jar string format madhye asel tar to direct read hot nahi mg tithe StringIO cha use karatat)

# %%
## Without StringIO

import pandas as pd

data= "name, age\n" \
"      Amit, 25\n " \
"      Sneha, 23"

pd.read_csv(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 7
#       1 import pandas as pd
#       3 data= "name, age\n" \
#       4 "      Amit, 25\n " \
#       5 "      Sneha, 23"
# ----> 7 pd.read_csv(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 22] Invalid argument: 'name, age\n      Amit, 25\n       Sneha, 23'

# %%
## With StringIO

import pandas as pd
from io import StringIO

data="name, age\n" \
"      Amit, 25\n " \
"      Sneha, 23"

df=pd.read_csv(StringIO(data))
print(df)
# Out:
#            name   age
# 0          Amit    25
# 1         Sneha    23

# %%
##Load a comma separated file (CSV file) into a DataFrame:

import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df) 
df = pd.read_csv("data.csv")
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# Empty DataFrame
# Columns: [hii hello]
# Index: []

# %% [markdown]
# A simple way to store big data sets is to use CSV files (comma separated files).
#
# CSV files contains plain text and is a well know format that can be read by everyone including Pandas.

# %%
## Load the CSV into a DataFrame:

import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df) ## without to_string()
print(df.to_string()) ## with to_string()

df = pd.read_csv("data.csv")
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# Empty DataFrame
# Columns: [hii hello]
# Index: []

# %% [markdown]
# - max_rows:-
#
# The number of rows returned is defined in Pandas option settings.
#
# You can check your system's maximum rows with the pd.options.display.max_rows statement.

# %%
##Increase the maximum number of rows to display the entire DataFrame:

import pandas as pd

pd.options.display.max_rows = 9999

df = pd.read_csv('data.csv')

print(df)
# Out:
# Empty DataFrame
# Columns: [hii hello]
# Index: []

# %% [markdown]
# ### Read JSON:
#
# Big data sets are often stored, or extracted as JSON.
#
# JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.

# %%
import pandas as pd

df = pd.read_json('data.json')
print(df)

print(df.to_string())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# ### Dictionary as JSON:
# If your JSON code is not in a file, but in a Python Dictionary, you can load it into a DataFrame directly:
#
# JSON = Python Dictionary
#
# JSON objects have the same format as Python dictionaries.

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# ### - Parameters :

# %% [markdown]
# ### 1. orient
#
# Defines the format/layout of JSON data
#
# Orient Value|	Meaning
# ------------|---------------------------
# 'records'	|    List of dictionaries
# 'columns'	|    Dict of column names
# 'index'	    |    Dict of index
# 'values'	|    Array only
# 'table'	    |    Table schema

# %%
pd.read_json("data.json", orient="records")
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
pd.read_json("data.json", orient="columns")
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
pd.read_json("data.json", orient="index")
# Out:
#             0    1    2    3    4    5
# Duration   60   60   60   45   45   60
# Pulse     110  117  103  109  117  102
# Maxpulse  130  145  135  175  148  127
# Calories  409  479  340  282  406  300

# %%
pd.read_json("data.json", orient="values")
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
import pandas as pd

pd.read_json("file.json", orient="table")
# Out:
#       age
# name
# Amit   20
# Neha   21

# %%
df = pd.read_json('data.json')
print(df)

df.to_json("data.csv", orient="index") ## dto_json() converts Pandas data into JSON format.
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
pd.json_normalize(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]
