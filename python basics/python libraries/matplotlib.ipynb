# %% [markdown]
# ### Matplotlib:
#
# -Matplotlib is a Python plotting library used to create 2D graphs and charts.
# -It helps us visualize data in the form of:
#
# Graphs
# Charts
# Plots
# Diagrams
#
# 📌 Used in:
# Data Science
# Machine Learning
# Data Analysis
# College projects
#
# 📌 Why used Matplotlib:
#
# -To convert numerical data into visual form
# -To easily analyze trends and patterns
# -To create high-quality and customizable graphs
# -To work smoothly with NumPy and Pandas
# -To support data science and machine learning projects

# %% [markdown]
# #### - Pyplot
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:
#
#     import matplotlib.pyplot as plt

# %%
## Draw a line in a diagram from position (1, 15) to position (4, 35):

import matplotlib.pyplot as plt

x = [1, 15]
y = [4, 35]

plt.plot(x, y)
plt.show()    # optional

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.show()

# %% [markdown]
# #### - plotting:
#
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.(x-axis: horizontal)
#
# Parameter 2 is an array containing the points on the y-axis.(y-axis: vertical)

# %%
## Draw a line in a diagram from position (1, 3) to position (8, 10):

import matplotlib.pyplot as plt

x=[1, 3]
y=[8, 10]

plt.plot(x, y)
plt.show()    # optional

# %% [markdown]
# #### - Markers
# You can use the keyword argument marker to emphasize each point with a specified marker
#
# You can choose any of these markers:
#
# Marker  |	Description
# --------|--------------------
# 'o'	    |    Circle
# '*'	    |    Star
# '.'	    |    Point
# ','	    |    Pixel
# 'x'	    |    X
# 'X'	    |    X (filled)
# '+'	    |    Plus
# 'P'	    |    Plus (filled)
# 's'	    |    Square
# 'D'	    |    Diamond
# 'd'	    |    Diamond (thin)
# 'p'	    |    Pentagon
# 'H'	    |    Hexagon
# 'h'	    |    Hexagon
# 'v'	    |    Triangle Down
# '^'	    |    Triangle Up
# '<'	    |    Triangle Left
# '>'	    |    Triangle Right
# '1'	    |    Tri Down
# '2'	    |    Tri Up
# '3'	    |    Tri Left
# '4'	    |    Tri Right
# '|'	    |    Vline
# '_'	    |    Hline

# %%
## Mark each point with a circle:

import matplotlib.pyplot as plt

ypoints =[3, 8, 1, 10]
xpoints=[0.3, 1.3, 2.3, 3.3]
plt.plot(xpoints, ypoints, marker = '|')
plt.show()

# %% [markdown]
# - Format Strings fmt:
#
# You can also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this
#
# -syntax:
#
#     marker|line|color
#
# -Line Reference:
#
# Line   | 	Description
# -------|------------------
# '-'	   |     Solid line
# ':'	   |     Dotted line
# '--'   |     Dashed line
# '-.'   |	 Dashed/dotted line
#
# -Color Reference
#
# Color  | 	Description
# -------|--------------------
# 'r'	   |     Red
# 'g'	   |     Green
# 'b'	   |     Blue
# 'c'	   |     Cyan
# 'm'	   |     Magenta
# 'y'	   |     Yellow
# 'k'	   |     Black
# 'w'	   |     White

# %%
import matplotlib.pyplot as plt

ypoints =[3, 8, 1, 10]

plt.plot(ypoints, 'o:g') # yellow green dotted line with circle markers  
plt.show()

# %% [markdown]
# -Marker Size:
#
# You can use the keyword argument markersize or the shorter version, 'ms' to set the size of the markers
#
#     marker size = ms
#
# -Marker Edge colour:
#
# You can use the keyword argument markeredgecolor or the shorter 'mec' to set the color of the edge of the markers
#
#     markeredgecolor = mec

# %%
import matplotlib.pyplot as plt

ypoints =[3, 8, 1, 10]

plt.plot(ypoints, 'o-', ms=10, mec='red') # red edge circle markers with solid line
plt.show()

# %% [markdown]
# -Marker Face Colour:
#
# You can use the keyword argument markerfacecolor or the shorter 'mfc' to set the color inside the edge of the markers
#
#     MarkerFaceColor = mfc

# %%
import matplotlib.pyplot as plt

ypoints =[3, 8, 1, 10]

plt.plot(ypoints, 'o-', ms=15, mfc='yellow') # yellow filled circle markers with solid line
plt.show()

# %% [markdown]
# #### - Line:
#
# You can use the keyword argument linestyle, or shorter 'ls', to change the style of the plotted line
#
#     linestyle = ls
#
# Style	  |     Or
# ----------|---------------
# 'solid'   | 	'-'
# 'dotted'  |      ':'
# 'dashed'  |	    '--'
# 'dashdot' |	    '-.'
# 'None'	  |      'or'

# %%
import matplotlib.pyplot as plt

ypoints =[3, 8, 1, 10]
xpoints=[0, 1, 2, 3]

plt.plot(ypoints, ls='--')
plt.plot(xpoints, ls='dotted')
plt.show()

# %% [markdown]
# -Line Color:
#
# You can use the keyword argument color or the shorter 'c' to set the color of the line
#
#     color = c

# %%
import matplotlib.pyplot as plt

ypoints =[3, 8, 1, 10]
xpoints=[0, 1, 2, 3]

plt.plot(ypoints, c='green')
plt.plot(xpoints, color="#AF784C")
plt.show()

# %% [markdown]
# -Line Width:
#
# You can use the keyword argument linewidth or the shorter 'lw' to change the width of the line.
#
# The value is a floating number
#
#     linewidth = lw

# %%
import matplotlib.pyplot as plt

ypoints =[3, 8, 1, 10]

plt.plot(ypoints, lw= 15.4)
plt.show()

# %% [markdown]
# #### - Labels:
#
# With Pyplot, you can use the xlabel() and ylabel() functions to set a label for the x- and y-axis.
#
#     set the label = xlabel, ylebel
#     set the title = tittle

# %%
## Add labels to the x- and y-axis:

import matplotlib.pyplot as plt

x = [80, 85, 90, 95, 100, 105, 110, 115, 120, 125]
y = [240, 250, 260, 270, 280, 290, 300, 310, 320, 330]

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# -Set Font Properties:
#
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.
#
# -Position the Title:
#
# You can use the loc parameter in title() to position the title.
#
# Legal values are:
#
#     'left', 'right', and 'center'. Default value is 'center'.

# %%
## Set font properties for the title and labels:

import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':17}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1, loc = 'left')  # tittle + position
plt.xlabel("Average Pulse", fontdict = font2)  # x-axis label with font properties
plt.ylabel("Calorie Burnage", fontdict = font2) # y-axis label with font properties

plt.plot(x, y, ':r')
plt.show()

# %% [markdown]
# #### - Grid():-
#
# With Pyplot, you can use the grid() function to add grid lines to the plot.

# %%
## Add grid lines to the plot:

import matplotlib.pyplot as plt

x = [80, 90, 100, 110, 120]
y = [240, 250, 260, 270, 280]

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# Only 'x' axis grid line

# %%
import matplotlib.pyplot as plt

x = [80, 90, 100, 110, 120]
y = [240, 250, 260, 270, 280]

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis='x') # only x-axis grid lines

plt.show()

# %% [markdown]
# Only 'y' axis grid line

# %%
import matplotlib.pyplot as plt

x = [80, 90, 100, 110, 120]
y = [240, 250, 260, 270, 280]

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis='y') # only y-axis grid lines

plt.show()

# %% [markdown]
# Custom the grid lines

# %%
import matplotlib.pyplot as plt

x = [80, 90, 100, 110, 120, 130, 140, 150, 160, 170, 180]
y = [240, 250, 260, 270, 280, 290, 300, 310, 320, 330, 340]

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color='red', linestyle='--', linewidth=0.5) # custom grid lines

plt.show()

# %% [markdown]
# #### - SubPlot:-
#
# Display Multiple Plots
#
# With the 'subplot()' function you can draw multiple plots in one figure

# %%
## Draw 2 plots:

import matplotlib.pyplot as plt

#plot 1:
x = [0, 1, 2, 3]
y = [3, 8, 1, 10]

plt.subplot(1, 2, 1) # 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

#plot 2:
x = [0, 1, 2, 3]
y = [10, 20, 30, 40]

plt.subplot(1, 2, 2) # 1 row, 2 columns, and this plot is the second plot.
plt.plot(x,y)

plt.show()

# %%
## Draw 2 plots:

import matplotlib.pyplot as plt

#plot 1:
x = [0, 1, 2, 3]
y = [3, 8, 1, 10]

plt.subplot(2, 1, 1) # 2 row, 1 columns, and this plot is the first plot.
plt.plot(x,y)

#plot 2:
x = [0, 1, 2, 3]
y = [10, 20, 30, 40]

plt.subplot(2, 1, 2) # 2 row, 1 columns, and this plot is the second plot.
plt.plot(x,y)

plt.show()

# %% [markdown]
# Draw 6 plots:-

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3]
y = [3, 8, 1, 10]

plt.subplot(2, 3, 1) # 2 row, 3 columns, and this plot is the first plot.
plt.plot(x,y)

x = [0, 1, 2, 3]
y = [10, 20, 30, 40]

plt.subplot(2, 3, 2) # 2 row, 3 columns, and this plot is the second plot.
plt.plot(x,y)

x = [0, 1, 2, 3]
y = [3, 8, 1, 10]

plt.subplot(2, 3, 3) # 2 row, 3 columns, and this plot is the third plot.
plt.plot(x,y)

x = [0, 1, 2, 3]
y = [10, 20, 30, 40]

plt.subplot(2, 3, 4) # 2 row, 3 columns, and this plot is the fourth plot.
plt.plot(x,y)

x = [0, 1, 2, 3]
y = [3, 8, 1, 10]

plt.subplot(2, 3, 5) # 2 row, 3 columns, and this plot is the fifth plot.
plt.plot(x,y)

x = [0, 1, 2, 3]
y = [10, 20, 30, 40]

plt.subplot(2, 3, 6) # 2 row, 3 columns, and this plot is the sixth plot.
plt.plot(x,y)

plt.show()

# %% [markdown]
# -Title:
#
# You can add a title to each plot with the title() function:

# %%
## 2 plots, with titles:

import matplotlib.pyplot as plt

#plot 1:
x = [0, 1, 2, 3]
y = [3, 8, 1, 10]

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES") # title for first plot

#plot 2:
x = [0, 1, 2, 3]
y = [10, 20, 30, 40]

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME") # title for second plot

plt.show()

# %% [markdown]
# -Super Title:
#
# You can add a title to the entire figure with the 'suptitle()' function

# %%
## 2 plots, with titles:

import matplotlib.pyplot as plt

#plot 1:
x = [0, 1, 2, 3]
y = [3, 8, 1, 10]

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES") # title for first plot

#plot 2:
x = [0, 1, 2, 3]
y = [10, 20, 30, 40]

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME") # title for second plot

plt.suptitle("MY SHOP") # overall title for both plots

plt.show()

# %% [markdown]
# #### - Scatter Plots:
#
# With Pyplot, you can use the 'scatter()' function to draw a scatter plot.
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Draw two plots on the same figure

# %%
import matplotlib.pyplot as plt

#day one, the age and speed of 13 cars:
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = [2,2,8,1,15,8,12,9,7,3,11,4,7,14,12]
y = [100,105,84,105,90,99,90,95,94,100,79,112,91,80,85]
plt.scatter(x, y)

plt.show()

# %% [markdown]
# -Colors:
#
# You can set your own color for each scatter plot with the color or the 'c' argument

# %%
import matplotlib.pyplot as plt

#day one, the age and speed of 13 cars:
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x, y, color = 'hotpink')

#day two, the age and speed of 15 cars:
x = [2,2,8,1,15,8,12,9,7,3,11,4,7,14,12]
y = [100,105,84,105,90,99,90,95,94,100,79,112,91,80,85]
plt.scatter(x, y, color = "#2c38dd")

plt.show()

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
colors = ["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"]

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# -ColorMap:-
#
# The Matplotlib module has a number of available colormaps.
#
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.
#
# -How to Use the ColorMap:-
#
# You can specify the colormap with the keyword argument 'cmap' with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
colors = [0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100]

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
colors = [0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100]

plt.scatter(x,y,c=colors,cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# -Size:
#
# You can change the size of the dots with the 's' argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
sizes = [20,50,100,200,500,550,60,90,10,300,600,510,75]

plt.scatter(x,y,s=sizes)

plt.show()

# %% [markdown]
# -Alpha:
#
# You can adjust the transparency of the dots with the alpha argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
sizes = [20,50,100,200,500,550,60,90,10,300,600,510,75]

plt.scatter(x,y,s=sizes,alpha=0.5, c='green')
plt.show()

# %% [markdown]
# -Combine Color Size and Alpha:
#
# You can combine a colormap with different sizes of the dots. This is best visualized if the dots are transparent

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Scatter plot with color, size, and alpha
plt.scatter(
    x, y,
    color='red',   # Color of points
    s=200,         # Size of points
    alpha=0.5      # Transparency (0 to 1)
)

plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Color + Size + Alpha Example")

plt.show()

# %%
## Create random arrays with 100 values for x-points, y-points, colors and sizes:

import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# #### -Bars:
#
# With Pyplot, you can use the bar() function to draw bar graphs

# %%
## Draw 4 bars:

import matplotlib.pyplot as plt

x = ["A", "B", "C", "D"]
y = [3, 8, 1, 10]

plt.bar(x,y)
plt.show()

# %% [markdown]
# -Horizontal Bars:
#
# If you want the bars to be displayed horizontally instead of vertically, use the 'barh()' function.

# %%
## Draw 4 horizontal bars:

import matplotlib.pyplot as plt
import numpy as np

x = ["A", "B", "C", "D"]
y = [3, 8, 1, 10]

plt.barh(x, y)
plt.show()

# %% [markdown]
# -Bar Color:
#
# The bar() and barh() take the keyword argument color to set the color of the bars.

# %%
## Draw 4 green bars:

import matplotlib.pyplot as plt

x = ["A", "B", "C", "D"]
y = [3, 8, 1, 10]

plt.bar(x, y, color = 'green')
plt.show()

# %% [markdown]
# Color Hex:
#
# Or you can use Hexadecimal color values

# %%
## Draw 4 brown bars:

import matplotlib.pyplot as plt

x = ["A", "B", "C", "D"]
y = [3, 8, 1, 10]

plt.bar(x, y, color = "#AF844C")
plt.show()

# %% [markdown]
# -Bar Width:
#
# The bar() takes the keyword argument width to set the width of the bars.

# %%
## Draw 4 very thin bars:

import matplotlib.pyplot as plt

x = ["A", "B", "C", "D"]
y = [3, 8, 1, 10]

plt.bar(x, y, width = 0.5)
plt.show()

# %% [markdown]
# -Bar Height:
#
# The barh() takes the keyword argument height to set the height of the bars

# %%
## Draw 4 very thin bars:

import matplotlib.pyplot as plt

x = ["A", "B", "C", "D"]
y = [3, 8, 1, 10]

plt.barh(x, y, height = 0.5)
plt.show()

# %% [markdown]
# #### - Histogram:-

# %% [markdown]
# A histogram is a graph showing frequency distributions.
#
# In Matplotlib, we use the hist() function to create histograms.
#
# The hist() function will use an array of numbers to create a histogram, the array is sent into the function as an argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250) # mean, stddev, number of values 

plt.hist(x)
plt.show()

# %%
## A Normal Data Distribution by NumPy:

import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [188.83990708 163.65873304 161.24471966 171.62945988 179.60719728
#  159.78506068 158.97371401 180.03752238 170.11211606 155.19882199
#  164.58087586 165.83306046 199.55048696 178.2774988  169.05209253
#  166.53734385 159.52116189 179.36983402 164.99525745 187.79023137
#  179.10648913 162.67860733 181.53875327 176.009973   162.28050692
#  160.18336095 170.78555033 167.36291443 171.66444448 159.8495342
#  188.17707496 188.30545396 167.28952114 167.37673323 187.51540484
#  174.57850391 178.31986367 175.27481374 178.36729769 160.41191644
#  164.13027634 167.01494662 160.44840257 174.47656454 168.91473538
#  154.76682923 159.77562652 165.30664616 163.8584705  172.19667103
#  176.24185239 168.18947652 168.39334785 164.48885242 179.83125326
#  174.91017779 187.85108953 150.92072977 180.95247734 178.68499578
#  178.72159955 169.50523635 167.07979234 151.64887411 186.05160384
#  172.50050356 157.38845858 181.35279777 179.56424389 154.94507395
# ...

# %% [markdown]
# #### -pie Chart:-

# %% [markdown]
# -Labels:
#
# Add labels to the pie chart with the labels parameter.
#
# The labels parameter must be an array with one label for each wedge

# %%
## A simple pie chart:

import matplotlib.pyplot as plt

y = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# -Start Angle:
#
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
#
# The startangle parameter is defined with an angle in degrees, default angle is 0.

# %%
import matplotlib.pyplot as plt

y = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# -Explode:
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed:

# %%
import matplotlib.pyplot as plt

y = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0, 0.1, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# -Shadow:
# Add a shadow to the pie chart by setting the shadows parameter to True

# %%
import matplotlib.pyplot as plt

y = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# -Colors:
#
# You can set the color of each wedge with the colors parameter.
#
# The colors parameter, if specified, must be an array with one value for each wedge
#
# colors:
#
# 'r' - Red
# 'g' - Green
# 'b' - Blue
# 'c' - Cyan
# 'm' - Magenta
# 'y' - Yellow
# 'k' - Black
# 'w' - White

# %%
import matplotlib.pyplot as plt

y = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# -Legend:
#
# To add a list of explanation for each wedge, use the legend() function.

# %%
import matplotlib.pyplot as plt

y = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# -Legend With Header:
#
# To add a header to the legend, add the title parameter to the legend function.

# %%
## Add a legend with a header:

import matplotlib.pyplot as plt

y = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()
