# %% [markdown]
# ### Seaborn:-

# %% [markdown]
# Seaborn is a data visualization library built on top of Matplotlib.
#
# Used to create beautiful, statistical graphs with less code.

# %% [markdown]
# - Why Seaborn?
#
# Works directly with Pandas DataFrames
#
# Better default styles & colors
#
# Easy statistical plots
#
# Less code than Matplotlib

# %% [markdown]
# - Different categories of plot in Seaborn
#
# Plots are basically used for visualizing the relationship between variables. Those variables can be either completely numerical or a category like a group, class, or division. Seaborn divides the plot into the below categories -
#
#
# Relational plots:
# This plot is used to understand the relation between two variables.
#
# Categorical plots:
# This plot deals with categorical variables and how they can be visualized.
#
# Distribution plots:
# This plot is used for examining univariate and bivariate distributions
#
# Regression plots:
# The regression plots in Seaborn are primarily intended to add a visual guide that helps to emphasize patterns in a dataset during exploratory data analyses.
#
# Matrix plots:
# A matrix plot is an array of scatterplots.
#
# Multi-plot grids:
# It is a useful approach to draw multiple instances of the same plot on different subsets of the dataset.

# %% [markdown]
# 1️⃣ Relational Plots (Relationships between variables):

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\jadha\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %% [markdown]
# 🔸 scatterplot:
#
# 👉 Shows relation between two numeric values

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips") # Load the "tips" dataset from seaborn

sns.scatterplot(x="total_bill", y="tip", data=df)
plt.show()

# %% [markdown]
# 🔸 lineplot:
#
# 👉 Trend over time / order

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")
sns.lineplot(x="size", y="tip", data=df)
plt.show()

# %% [markdown]
# 🔸 relplot (figure-level)

# %%
sns.relplot(x="total_bill", y="tip", kind="line", data=df) # Create a relational plot with line kind(line, scatter)

# %% [markdown]
# 2️⃣ Categorical Plots (Category-wise comparison):
#
# 🔸 barplot:
# 👉 Shows mean value

# %%
sns.barplot(x="day", y="total_bill", data=df)
plt.show()

# %% [markdown]
# 🔸 countplot:
#
# 👉 Counts frequency

# %%
sns.countplot(x="day", data=df)
plt.show()

# %% [markdown]
# 🔸 boxplot
#
# 👉 Shows:
#
# min
#
# max
#
# median
#
# outliers

# %%
sns.boxplot(x="day", y="total_bill", data=df)
plt.show(max)

# %% [markdown]
# 🔸 violinplot
#
# 👉 Boxplot + density

# %%
sns.violinplot(x="day", y="total_bill", data=df)
plt.show()

# %% [markdown]
# 🔸 stripplot

# %%
sns.stripplot(x="day", y="total_bill", data=df)
plt.show()

# %% [markdown]
# 🔸 swarmplot

# %%
sns.swarmplot(x="day", y="total_bill", data=df)
plt.show()

# %% [markdown]
# 🔸 catplot (figure-level)

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=df)

# %% [markdown]
# 3️⃣ Distribution Plots (Data spread)
#
# 🔸 histplot
#
# Seaborn Histplot is used to visualize the distribution of a single variable (univariate data).
# It shows how data values are spread across intervals (bins).

# %%
sns.histplot(df["total_bill"], bins=5) # Create a histogram of the "total_bill" column with 5 bins
plt.show()

# %% [markdown]
# 🔸 kdeplot
#
# 👉 Smooth curve (density)
#
# Shows Kernel Density Estimate
#
# Smooth curve over histogram
#
# Default is False

# %%
sns.kdeplot(df["total_bill"])
plt.show()

# %% [markdown]
# 🔸 displot
#
# Seaborn distplot() is used to visualize the distribution of a single variable (univariate data).

# %%
sns.displot(df["total_bill"], kind="hist")

# %% [markdown]
# - distplot():
#
# distplot() is deprecated in newer Seaborn versions and is replaced by:
#
# histplot()
#
# kdeplot()
#
# displot()

# %% [markdown]
# 4️⃣ Regression Plots (Trend + relationship):
#
# 🔸 regplot
#
# 👉 Scatter + regression line

# %%
sns.regplot(x="total_bill", y="tip", data=df)
plt.show()

# %% [markdown]
# 🔸 lmplot

# %%
sns.lmplot(x="total_bill", y="tip", data=df)

# %% [markdown]
# 5️⃣ Matrix Plots (Correlation & Heatmaps):
#
# 🔸 heatmap
#
# 👉 Very important for ML & Data Analysis

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# 6️⃣ Multi-Plot Grids
#
# 🔸 pairplot
#
# 👉 Plots relationships between all numeric columns

# %%
sns.pairplot(df)

# %% [markdown]
# 🔸 facetgrid

# %%
g = sns.FacetGrid(df, col="day")
g.map(sns.histplot, "total_bill")

# %% [markdown]
# #### - Styling & Themes
#
# 🔸 Set theme
#
# Styles:
#
# darkgrid
#
# whitegrid
#
# dark
#
# white
#
# ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")
sns.lineplot(x="size", y="tip", data=df)
sns.set_theme(style="darkgrid")
plt.show()

# %% [markdown]
# 🔸 Color palettes
#
# Popular palettes:
#
# deep
#
# muted
#
# bright
#
# pastel
#
# Set1, Set2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")
sns.lineplot(x="size", y="tip", data=df)
sns.color_palette("pastel")
sns.set_palette("Set2") # set 1,2,3 ..... colors
plt.show()

# %% [markdown]
# #### - Hue, Size & Style
#
# 👉 Multiple info in one plot

# %%
sns.scatterplot(
    x="total_bill",
    y="tip",
    hue="sex",
    size="size",
    style="time",
    data=df
)
plt.show()
