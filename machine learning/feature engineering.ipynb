# %% [markdown]
# ### Feature Engineering:
#
# Feature engineering is the process of using domain knowledge to extract the features from raw data. These features can be used to improve the performance of machine learning algorithms.
#
# - Why is Feature Engineering Important?
#
# Raw data is dirty, incomplete, and unbalanced
# ML models learn only from features
# Better features = higher accuracy + faster training
#
# 📍 Many times, feature engineering is more important than choosing the algorithm.

# %% [markdown]
# - Types Of Feature Engineering:
#
# 1. |---Feature Transformation
# 2. |---Feature Construction
# 3. |---Feature Selection
# 4. |---Feature Extraction

# %% [markdown]
# 1. Feature Tranformation:-
#
# Feature Transformation means changing the form or scale of existing features.
# Changing existing data so it becomes clean, comparable, and meaningful.
#
# Types -
# a. Missing Value Handling
# b. Handling catagorial Feature
# c. Outlier Handling
# d. Feature Scalling
#
# a. Missing Value Handling:
#
# Why problem?
# ML cannot learn from empty values.
#
# Example:
# Age	Salary
# 25	30000
# NaN	40000
#
# ❌ Model confused: What is NaN?
#
# ✔ Solution:
# Replace with mean age = 30
# Or remove row
#
# ➡ Now data is complete ✅
#
# ----------------------------------
# b. Handling Categorical Features:
#
# ❓ Why?
# ML understands numbers, not words.
#
# Example:
# City
# Pune
# Mumbai
#
# ❌ Model cannot process text
#
# ✔ Encoding:
#
# One-Hot Encoding:
#
# Pune|	Mumbai
# ----|------------
# 1   |	0
# 0   |   1
#
# ➡ Now machine understands ✔
#
# --------------------------------
#
# c. Outlier Handling
#
# ❓ What is outlier?
# Value that is too big or too small, often wrong.
#
# Example:
# Salary
# 30000
# 35000
# 5000000 ❌
#
# ❌ This one value pulls model badly
#
# ✔ Solution:
#
# Remove
# Cap value
# Log transform
#
# ➡ Model becomes stable ✔
#
# ---------------------------------
# d. Feature scalling:
#
# Feature Scaling is the process of bringing numerical features to a common scale so that one feature does not dominate others.
#
# -Types of Feature Scaling:
#
# 1. Normalization (Min–Max Scaling)
# 2. Standardization (Z-score Scaling)

# %% [markdown]
# 2. Feature Construction:
#
# Feature Construction is the process of creating new, meaningful features from existing features
# to help a machine learning model learn patterns more effectively.
#
# Example:
#
# 🎓 Student Performance Prediction
#
# Raw Features:
#
# Study hours
# Attendance
#
# Constructed Feature:
# 👉 Performance Score = Study hours × Attendance
#
# ➡ This single feature explains performance better than using both separately.

# %% [markdown]
# 3. Feature Selection:
#
# Feature Selection is the process of choosing the most relevant and important features and removing unnecessary or irrelevant features from the dataset.
#
# Example:
#
# 🎓 Student Marks Prediction
#
# All Features:
#
# Study hours ✔
# Attendance ✔
# Student name ❌
# Roll number ❌
#
# ❌ Name and roll number do not affect marks
#
# ✔ After feature selection:
#
# Study hours
# Attendance
#
# ➡ Model becomes simpler and more accurate

# %% [markdown]
# 4. Feature Extraction:
#
# Feature Extraction is the process of transforming raw data into a new set of reduced and meaningful features
# while preserving important information.
#
# -completely new data tayar karato
#
# Example:
#
# Image Data
#
# An image of size 100 × 100 pixels
# ➡ 10,000 features ❌
#
# After feature extraction:
# ➡ 50–100 important features ✔
#
# Model becomes faster and more accurate.
